# %% [markdown]
# ***Credit Card Approval Prediction***

# %% [markdown]
# **Background Introduction**
#
# Credit cards serve as a prevalent risk control mechanism within the financial sector. They leverage personal data and information provided by credit card applicants to forecast the likelihood of future defaults and credit card borrowings. Understanding and predicting these patterns is crucial for financial institutions to manage risks effectively and make informed lending decisions.
#
# **The Approach**
#
# **Quick Exploratory Data Analysis (EDA):**
#
# --> Understand the structure and distribution of the data.
# --> Identify any patterns, anomalies, or correlations within the dataset.
# --> Visualize key features to gain insights and intuition about the data.
#
# **Feature Engineering:**
#
# --> Transform existing variables to derive new meaningful features.
# --> Handle missing values, outliers, and skewed distributions.
# --> Create interaction terms or polynomial features to capture non-linear relationships.
#
# **Encoder:**
#
# --> Encode categorical variables into numerical format using techniques like one-hot encoding or label encoding.
# --> Ensure the data is in a format suitable for modeling.
#
# **Model Evaluation & Comparison:**
#
# --> Split the dataset into training and testing subsets to evaluate model performance.
# --> Use appropriate metrics such as accuracy, precision, recall, and F1-score to evaluate the models.
# --> Compare the performance of different classification algorithms to identify the most suitable one for the dataset.
#
# **Classification Models to be Evaluated:**
#
# --> **Logistic Regression:** A linear model used for binary classification, estimating the probability of a given instance belonging to a particular category.
#
# --> **K-Nearest Neighbors (KNeighbors):** A non-parametric method used for classification and regression, which classifies a data point based on how its neighbors are classified.
#
# --> **Support Vector Classifier (SVC):** A powerful classification algorithm that finds the hyperplane that best separates the classes in a high-dimensional space.
#
# --> **Decision Tree:** A tree-like model used for classification that breaks down a dataset into smaller subsets based on different conditions, making decisions based on the features at each node.
#
# --> **Random Forest:** An ensemble learning method that constructs multiple decision trees during training and outputs the class that is the mode of the classes of individual trees.
#
# ***Target Cluster Datasets Description***
#
# The target cluster dataset focuses on predicting profit based on a comprehensive set of fields. Here's a breakdown of the features included in the dataset:
#
# **Binary Features:**
#
# --> Gender: Gender code of the applicant (e.g., Male, Female)
# --> Has_a_car: Indicates if the applicant owns a car (Yes/No)
# --> Has_a_property: Indicates if the applicant owns real estate (Yes/No)
# --> Has-a_work_phone: Indicates if the applicant has a work phone (1/0)
# --> Has_a_phone: Indicates if the applicant has a personal phone (1/0)
# --> Has_an_email: Indicates if the applicant has provided an email address (1/0)
#
# **Non-Binary Categorical Features:**
#
# --> Children_count: Number of children the applicant has
# --> Employment_status: Type of income of the applicant (e.g., Working, Commercial associate, Pensioner, etc.)
# --> Education_level: Education level of the applicant (e.g., Secondary / secondary special, Higher education, Incomplete higher, etc.)
# --> Marital_status: Family status of the applicant (e.g., Single / not married, Married, Civil marriage, etc.)
# --> Dwelling: Housing situation of the applicant (e.g., House / apartment, Rented apartment, With parents, etc.)
# --> Job_title: Occupation type of the applicant (e.g., Laborers, Sales staff,Accountants, Core staff, Managers, etc.)
# --> Family_member_count: Number of family members of the applicant
#
# **Continuous Features:**
#
# --> Income: Amount of income of the applicant
# --> Age: Number of days since the applicant was born (can be negative)
# --> Employment_length: Number of days the applicant has been employed (can be negative)
#
# **Constant Feature:**
#
# --> Has_a_mobile_phone: Indicates if the applicant has a mobile phone (Constant value across all records)

# %%
# Importing necessary packages for data analysis and modeling
import os 
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import table_nan_val as tnv
import execdata as data
import itertools

# %%
# Read the dataset into a pandas DataFrame
df = pd.read_csv("train_data.csv")
df
# Out:
#             ID Gender Has_a_car Has_a_property  Children_count    Income  \
# 0      5037048      M         Y              Y               0  135000.0
# 1      5044630      F         Y              N               1  135000.0
# 2      5079079      F         N              Y               2  180000.0
# 3      5112872      F         Y              Y               0  360000.0
# 4      5105858      F         N              N               0  270000.0
# ...        ...    ...       ...            ...             ...       ...
# 29160  5067139      F         N              Y               0  112500.0
# 29161  5029193      F         N              Y               1  135000.0
# 29162  5047710      F         N              Y               0   76500.0
# 29163  5009886      F         N              Y               0  157500.0
# 29164  5062632      F         N              Y               0  585000.0
#
#           Employment_status                Education_level  \
# ...

# %%
# Print the shape of dataset to check the number of rows and columns in each DataFrame
df.shape
# Out:
# (29165, 20)

# %%
# Display column names of df to understand the structure of the dataset
df.columns.values
# Out:
# array(['ID', 'Gender', 'Has_a_car', 'Has_a_property', 'Children_count',
#        'Income', 'Employment_status', 'Education_level', 'Marital_status',
#        'Dwelling', 'Age', 'Employment_length', 'Has_a_mobile_phone',
#        'Has-a_work_phone', 'Has_a_phone', 'Has_an_email', 'Job_title',
#        'Family_member_count', 'Account_age', 'Is_high_risk'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29165 entries, 0 to 29164
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   29165 non-null  int64
#  1   Gender               29165 non-null  object
#  2   Has_a_car            29165 non-null  object
#  3   Has_a_property       29165 non-null  object
#  4   Children_count       29165 non-null  int64
#  5   Income               29165 non-null  float64
#  6   Employment_status    29165 non-null  object
#  7   Education_level      29165 non-null  object
#  8   Marital_status       29165 non-null  object
#  9   Dwelling             29165 non-null  object
#  10  Age                  29165 non-null  int64
#  11  Employment_length    29165 non-null  int64
#  12  Has_a_mobile_phone   29165 non-null  int64
#  13  Has-a_work_phone     29165 non-null  int64
#  14  Has_a_phone          29165 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  ID  Children_count        Income           Age  \
# count  2.916500e+04    29165.000000  2.916500e+04  29165.000000
# mean   5.078232e+06        0.430790  1.868904e+05 -15979.477490
# std    4.182400e+04        0.741882  1.014096e+05   4202.997485
# min    5.008804e+06        0.000000  2.700000e+04 -25152.000000
# 25%    5.042047e+06        0.000000  1.215000e+05 -19444.000000
# 50%    5.074666e+06        0.000000  1.575000e+05 -15565.000000
# 75%    5.114629e+06        1.000000  2.250000e+05 -12475.000000
# max    5.150485e+06       19.000000  1.575000e+06  -7705.000000
#
#        Employment_length  Has_a_mobile_phone  Has-a_work_phone   Has_a_phone  \
# count       29165.000000             29165.0      29165.000000  29165.000000
# mean        59257.761255                 1.0          0.224310      0.294977
# std        137655.883458                 0.0          0.417134      0.456040
# min        -15713.000000                 1.0          0.000000      0.000000
# ...

# %%
# Verify if the data types of each column match the corresponding column types
# Display similar information as df.info()
df.dtypes
# Out:
# ID                       int64
# Gender                  object
# Has_a_car               object
# Has_a_property          object
# Children_count           int64
# Income                 float64
# Employment_status       object
# Education_level         object
# Marital_status          object
# Dwelling                object
# Age                      int64
# Employment_length        int64
# Has_a_mobile_phone       int64
# Has-a_work_phone         int64
# Has_a_phone              int64
# Has_an_email             int64
# Job_title               object
# Family_member_count      int64
# Account_age              int64
# Is_high_risk             int64
# dtype: object

# %%
# Perform missing value analysis to identify any null or missing values in df
tnv.Missing_Value_Analysis(df)
# Out:
# Your selected dataframe has 20 columns.
# There are 1 columns that have missing values.
#        index  Miss_Values  Miss_Rate  Available_Value
# 0  Job_title         9027      30.95            20138

# %%
print(f'Duplicates in applications df: {df.iloc[:,1:].duplicated().sum()}, ({np.round(100*df.iloc[:,1:].duplicated().sum()/len(df),1)}%)')
# Out:
# Duplicates in applications df: 2786, (9.6%)

# %%
# Display the number of unique values for each column in df1
df.nunique()
# Out:
# ID                     29165
# Gender                     2
# Has_a_car                  2
# Has_a_property             2
# Children_count             9
# Income                   259
# Employment_status          5
# Education_level            5
# Marital_status             5
# Dwelling                   6
# Age                     6794
# Employment_length       3483
# Has_a_mobile_phone         1
# Has-a_work_phone           2
# Has_a_phone                2
# Has_an_email               2
# Job_title                 18
# Family_member_count       10
# Account_age               61
# Is_high_risk               2
# dtype: int64

# %%
# Remove duplicate rows based on all columns except the first one
df=df.drop_duplicates(subset=df.columns[1:], keep='first')
df.shape
# Out:
# (26379, 20)

# %%
# Fill missing values in the 'Job_title' column with 'Other'
df['Job_title'].fillna(value='Other', inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26379 entries, 0 to 29164
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   26379 non-null  int64
#  1   Gender               26379 non-null  object
#  2   Has_a_car            26379 non-null  object
#  3   Has_a_property       26379 non-null  object
#  4   Children_count       26379 non-null  int64
#  5   Income               26379 non-null  float64
#  6   Employment_status    26379 non-null  object
#  7   Education_level      26379 non-null  object
#  8   Marital_status       26379 non-null  object
#  9   Dwelling             26379 non-null  object
#  10  Age                  26379 non-null  int64
#  11  Employment_length    26379 non-null  int64
#  12  Has_a_mobile_phone   26379 non-null  int64
#  13  Has-a_work_phone     26379 non-null  int64
#  14  Has_a_phone          26379 non-null  int64
# ...

# %%
# Drop the constant feature 'Has_a_mobile_phone' where all values are the same
df.drop('Has_a_mobile_phone', axis=1, inplace=True)

# %%
df
# Out:
#             ID Gender Has_a_car Has_a_property  Children_count    Income  \
# 0      5037048      M         Y              Y               0  135000.0
# 1      5044630      F         Y              N               1  135000.0
# 2      5079079      F         N              Y               2  180000.0
# 3      5112872      F         Y              Y               0  360000.0
# 4      5105858      F         N              N               0  270000.0
# ...        ...    ...       ...            ...             ...       ...
# 29159  5091339      F         N              Y               0  135000.0
# 29161  5029193      F         N              Y               1  135000.0
# 29162  5047710      F         N              Y               0   76500.0
# 29163  5009886      F         N              Y               0  157500.0
# 29164  5062632      F         N              Y               0  585000.0
#
#           Employment_status                Education_level  \
# ...

# %%
# Extract the minimum 'Account_age' (indicating how many months the account has been open) for each 'ID' in df
start_df=pd.DataFrame(df.groupby(['ID'])['Account_age'].agg(min)).reset_index()

# Make the 'Account_age' values positive by multiplying by -1
start_df['Account_age']=-start_df['Account_age']

# %%
# Convert 'Age' to 'AGE_YEARS' in years
df['AGE_YEARS']=-df['Age']/365.2425

# Drop the 'Age' column
df.drop('Age', axis=1, inplace=True)

# %%
# Create an 'UNEMPLOYED' indicator column and set initial values to 0
df['UNEMPLOYED']=0

# Update 'UNEMPLOYED' values to 1 where 'DAYS_EMPLOYED' is negative
df.loc[-df['Employment_length']<0,'UNEMPLOYED']=1

# %%
# Convert 'Employment_length' to 'YEARS_EMPLOYED' in years
df['YEARS_EMPLOYED']=-df['Employment_length']/365.2425

# Set negative 'YEARS_EMPLOYED' values to 0
df.loc[df['YEARS_EMPLOYED']<0,'YEARS_EMPLOYED']=0

# Drop the 'Employment_length' column
df.drop('Employment_length', axis=1, inplace=True)

# %%
# Encode binary features using label encoding
df["Gender"] =  df["Gender"].replace(['F','M'],[0,1])
df["Has_a_car"] = df["Has_a_car"].replace(["Y","N"],[1,0])
df["Has_a_property"] = df["Has_a_property"].replace(["Y","N"],[1,0])

# %%
# Rename columns in the DataFrame df for better readability
df = df.rename(columns=
               {'Has_a_car': 'OwnCar',
                'Has_a_property':'OwnProperty',
                'Children_count':'NumOfChildren',
                'Employment_status':'IncomeType',
                'Education_level':'EducationLevel',
                'Marital_status':'FamilyStatus',
                'Has-a_work_phone':'WorkPhone',
                'Has_a_phone':'Phone',
                'Has_an_email':'Email',
                'Job_title':'OccupationType',
                'Family_member_count':'NumOfFamilyMember',
                'Is_high_risk':'Risk_TargetVariable',
                'Account_age':'AccountActivateLength',
                'AGE_YEARS':'Age',
                'UNEMPLOYED':'UnemployedStatus',
                'YEARS_EMPLOYED':'YearsOfEmployed'})

# %%
# Convert 'NumOfFamilyMember' column to integer data type
df['NumOfFamilyMember']=df['NumOfFamilyMember'].astype(int)

# %%
# Reorder columns in the DataFrame df for better organization and readability
df=df[['ID',
       'Gender',
       'Age',
       'UnemployedStatus',
       'YearsOfEmployed',  
       'OccupationType',
       'IncomeType',
       'Income',
       'EducationLevel',
       'Dwelling',
       'OwnCar',
       'OwnProperty', 
       'FamilyStatus',
       'NumOfChildren',
       'NumOfFamilyMember', 
       'AccountActivateLength',
       'WorkPhone',
       'Phone',
       'Email',
       'Risk_TargetVariable']]

# %%
# Save the processed DataFrame df to a CSV file without index
df.to_csv('processed_dataset_train.csv',index=False)

# %% [markdown]
# ***Feature Enginering***

# %%
df.columns
# Out:
# Index(['ID', 'Gender', 'Age', 'UnemployedStatus', 'YearsOfEmployed',
#        'OccupationType', 'IncomeType', 'Income', 'EducationLevel', 'Dwelling',
#        'OwnCar', 'OwnProperty', 'FamilyStatus', 'NumOfChildren',
#        'NumOfFamilyMember', 'AccountActivateLength', 'WorkPhone', 'Phone',
#        'Email', 'Risk_TargetVariable'],
#       dtype='object')

# %%
df = data.encode(df)
df
# Out:
#             ID  Gender        Age  UnemployedStatus  YearsOfEmployed  \
# 0      5037048       1  44.548485                 0         8.517629
# 1      5044630       0  27.734998                 0         4.520284
# 2      5079079       0  35.102706                 0        15.488340
# 3      5112872       0  57.301656                 0         5.601758
# 4      5105858       0  44.373259                 0         1.410022
# ...        ...     ...        ...               ...              ...
# 29159  5091339       0  30.357913                 0         3.961751
# 29161  5029193       0  42.525172                 0        22.604160
# 29162  5047710       0  48.685462                 0         9.010452
# 29163  5009886       0  59.234618                 1         0.000000
# 29164  5062632       0  51.631450                 0         5.503193
#
#        OccupationType  IncomeType    Income  EducationLevel  Dwelling  OwnCar  \
# ...

# %%
X_train, X_test, y_train, y_test = data.split(df)

# %%
train_score, test_score, models = data.model_evaluate(X_train, X_test, y_train, y_test)
# Out:
# model list is ['LogisticRegression', 'KNeighbors', 'SVC', 'DecisionTree', 'RandomForest']
# for model LogisticRegression with the train_score:0.9809505757475241 and test_score:0.9835102350265352
# for model KNeighbors with the train_score:0.981993081552386 and test_score:0.9829416224412434
# for model SVC with the train_score:0.9809505757475241 and test_score:0.9835102350265352
# for model DecisionTree with the train_score:0.9989101075676444 and test_score:0.9666413949962093
# for model RandomForest with the train_score:0.9988627209401507 and test_score:0.9812357846853677

# %%
train_score
# Out:
# [0.9809505757475241,
#  0.981993081552386,
#  0.9809505757475241,
#  0.9989101075676444,
#  0.9988627209401507]

# %%
test_score
# Out:
# [0.9835102350265352,
#  0.9829416224412434,
#  0.9835102350265352,
#  0.9666413949962093,
#  0.9812357846853677]
